# %% [markdown]
# <a href="https://colab.research.google.com/github/Eghosa-Osayande/fyb-project/blob/main/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# %mkdir GITHUB
# %cd GITHUB/
username="Eghosa-Osayande"
repository="litter_collecting_robot"

# !git clone https://github.com/{username}/{repository}

#uninstall openCV
#Twice'y'Enter
# !pip3 uninstall opencv-python opencv-contrib-python

#install openCV
# !pip3 install opencv-python==3.4.16.59 opencv-contrib-python==3.4.16.59
#Session restart
# exit()
# Out:
# /content/drive/MyDrive

# %%
# %cd /content/drive/MyDrive/GITHUB/litter_collecting_robot/cascade_training/train_cascade/

# %%
# !opencv_traincascade -data cascade3/ -vec pos.vec -bg neg.txt -precalcValBufSize 4000 -precalcIdxBufSize 4000 -numPos 150 -numNeg 90 -numStages 12 -w 24 -h 24 -maxFalseAlarmRate 0.4 -minHitRate 0.999
# Out:
# PARAMETERS:
# cascadeDirName: cascade2/
# vecFileName: pos.vec
# bgFileName: neg.txt
# numPos: 150
# numNeg: 90
# numStages: 12
# precalcValBufSize[Mb] : 4000
# precalcIdxBufSize[Mb] : 4000
# acceptanceRatioBreakValue : -1
# stageType: BOOST
# featureType: HAAR
# sampleWidth: 24
# sampleHeight: 24
# boostType: GAB
# minHitRate: 0.999
# maxFalseAlarmRate: 0.4
# weightTrimRate: 0.95
# maxDepth: 1
# maxWeakCount: 100
# mode: BASIC
# Number of unique features given windowSize [24,24] : 162336
#
# ===== TRAINING 0-stage =====
# <BEGIN
# POS count : consumed   150 : 150
# NEG count : acceptanceRatio    90 : 1
# Precalculation time: 2
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2|        1|        1|
# +----+---------+---------+
# |   3|        1| 0.533333|
# +----+---------+---------+
# |   4|        1| 0.544444|
# +----+---------+---------+
# |   5|        1| 0.255556|
# ...
